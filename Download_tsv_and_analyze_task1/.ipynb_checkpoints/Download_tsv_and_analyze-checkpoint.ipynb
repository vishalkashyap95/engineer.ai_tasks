# %%
import pandas as pd

# %%
df = pd.read_csv("https://ddbj.nig.ac.jp/public/mirror_database/1000genomes/20131219.populations.tsv",sep="\t")

# %%
df.dropna(how="any",inplace=True)

# %%
df.head(100)
# Out:
#                                Population Description Population Code  \
# 0                 Chinese Dai in Xishuangbanna, China             CDX
# 1                        Han Chinese in Bejing, China             CHB
# 2                            Japanese in Tokyo, Japan             JPT
# 3                   Kinh in Ho Chi Minh City, Vietnam             KHV
# 4                         Southern Han Chinese, China             CHS
# 5                               Bengali in Bangladesh             BEB
# 6                       Gujarati Indian in Houston,TX             GIH
# 7                             Indian Telugu in the UK             ITU
# 8                          Punjabi in Lahore,Pakistan             PJL
# 9                          Sri Lankan Tamil in the UK             STU
# 10                   African Ancestry in Southwest US             ASW
# 11                      African Caribbean in Barbados             ACB
# 12                                    Esan in Nigeria             ESN
# 13            Gambian in Western Division, The Gambia             GWD
# 14                             Luhya in Webuye, Kenya             LWK
# 15                              Mende in Sierra Leone             MSL
# 16                          Yoruba in Ibadan, Nigeria             YRI
# 17                    British in England and Scotland             GBR
# 18                                 Finnish in Finland             FIN
# 19                       Iberian populations in Spain             IBS
# 20                                   Toscani in Italy             TSI
# 21  Utah residents with Northern and Western Europ...             CEU
# 22                    Colombian in Medellin, Colombia             CLM
# 23        Mexican Ancestry in Los Angeles, California             MXL
# 24                             Peruvian in Lima, Peru             PEL
# 25                        Puerto Rican in Puerto Rico             PUR
#
#    Super Population DNA from Blood Offspring available from trios  \
# 0               EAS             no                            yes
# 1               EAS             no                             no
# 2               EAS             no                             no
# 3               EAS            yes                            yes
# 4               EAS             no                            yes
# 5               SAS             no                            yes
# 6               SAS             no                            yes
# 7               SAS            yes                            yes
# 8               SAS            yes                            yes
# 9               SAS            yes                            yes
# 10              AFR             no                            yes
# 11              AFR            yes                            yes
# 12              AFR             no                            yes
# 13              AFR             no                            yes
# 14              AFR             no                            yes
# 15              AFR             no                            yes
# 16              AFR             no                            yes
# 17              EUR             no                            yes
# 18              EUR             no                             no
# 19              EUR             no                            yes
# 20              EUR             no                             no
# 21              EUR             no                            yes
# 22              AMR             no                            yes
# 23              AMR             no                            yes
# 24              AMR            yes                            yes
# 25              AMR            yes                            yes
#
#     Pilot Samples  Phase1 Samples  Final Phase Samples  Total
# 0             0.0             0.0                 99.0   99.0
# 1            91.0            97.0                103.0  106.0
# 2            94.0            89.0                104.0  105.0
# 3             0.0             0.0                101.0  101.0
# 4             0.0           100.0                108.0  112.0
# 5             0.0             0.0                 86.0   86.0
# 6             0.0             0.0                106.0  106.0
# 7             0.0             0.0                103.0  103.0
# 8             0.0             0.0                 96.0   96.0
# 9             0.0             0.0                103.0  103.0
# 10            0.0            61.0                 66.0   66.0
# 11            0.0             0.0                 96.0   96.0
# 12            0.0             0.0                 99.0   99.0
# 13            0.0             0.0                113.0  113.0
# 14          102.0            97.0                101.0  116.0
# 15            0.0             0.0                 85.0   85.0
# 16          106.0            88.0                109.0  116.0
# 17            0.0            89.0                 92.0   94.0
# 18            0.0            93.0                 99.0  100.0
# 19            0.0            14.0                107.0  107.0
# 20           66.0            98.0                108.0  110.0
# 21           94.0            85.0                 99.0  103.0
# 22            0.0            60.0                 94.0   95.0
# 23            0.0            66.0                 67.0   69.0
# 24            0.0             0.0                 86.0   86.0
# 25            0.0            55.0                105.0  105.0

# %%
df.columns
# Out:
# Index(['Population Description', 'Population Code', 'Super Population',
#        'DNA from Blood', 'Offspring available from trios', 'Pilot Samples',
#        'Phase1 Samples', 'Final Phase Samples', 'Total'],
#       dtype='object')

# %%
df['Pilot Samples'].astype('int').mean()
# Out:
# 21.26923076923077

# %%
df['Phase1 Samples'].astype('int').mean()
# Out:
# 42.0

# %%
df['Pilot Samples'].fillna(0).astype('int').sum()
# Out:
# 1106

# %%
df[['Phase1 Samples','Final Phase Samples']].sum()
# Out:
# Phase1 Samples         2184.0
# Final Phase Samples    5070.0
# dtype: float64

# %%
import logging

# %%
logging.basicConfig(filename="analysis_app.log",format='%(asctime)s %(message)s',filemode='a')

# %%
# logger = logging.getLogger()

# %%
logger.log(10,"This is test log message for lvl 10, debug mode")

# %%
logger.debug("This test log for debug mode",exc_info=True)

# %%
df.head(100)
# Out:
#                                Population Description Population Code  \
# 0                 Chinese Dai in Xishuangbanna, China             CDX
# 1                        Han Chinese in Bejing, China             CHB
# 2                            Japanese in Tokyo, Japan             JPT
# 3                   Kinh in Ho Chi Minh City, Vietnam             KHV
# 4                         Southern Han Chinese, China             CHS
# 5                               Bengali in Bangladesh             BEB
# 6                       Gujarati Indian in Houston,TX             GIH
# 7                             Indian Telugu in the UK             ITU
# 8                          Punjabi in Lahore,Pakistan             PJL
# 9                          Sri Lankan Tamil in the UK             STU
# 10                   African Ancestry in Southwest US             ASW
# 11                      African Caribbean in Barbados             ACB
# 12                                    Esan in Nigeria             ESN
# 13            Gambian in Western Division, The Gambia             GWD
# 14                             Luhya in Webuye, Kenya             LWK
# 15                              Mende in Sierra Leone             MSL
# 16                          Yoruba in Ibadan, Nigeria             YRI
# 17                    British in England and Scotland             GBR
# 18                                 Finnish in Finland             FIN
# 19                       Iberian populations in Spain             IBS
# 20                                   Toscani in Italy             TSI
# 21  Utah residents with Northern and Western Europ...             CEU
# 22                    Colombian in Medellin, Colombia             CLM
# 23        Mexican Ancestry in Los Angeles, California             MXL
# 24                             Peruvian in Lima, Peru             PEL
# 25                        Puerto Rican in Puerto Rico             PUR
# 26                                              Total             NaN
# 27                                                NaN             NaN
# 28                                                NaN             NaN
#
#    Super Population DNA from Blood Offspring available from trios  \
# 0               EAS             no                            yes
# 1               EAS             no                             no
# 2               EAS             no                             no
# 3               EAS            yes                            yes
# 4               EAS             no                            yes
# 5               SAS             no                            yes
# 6               SAS             no                            yes
# 7               SAS            yes                            yes
# 8               SAS            yes                            yes
# 9               SAS            yes                            yes
# 10              AFR             no                            yes
# 11              AFR            yes                            yes
# 12              AFR             no                            yes
# 13              AFR             no                            yes
# 14              AFR             no                            yes
# 15              AFR             no                            yes
# 16              AFR             no                            yes
# 17              EUR             no                            yes
# 18              EUR             no                             no
# 19              EUR             no                            yes
# 20              EUR             no                             no
# 21              EUR             no                            yes
# 22              AMR             no                            yes
# 23              AMR             no                            yes
# 24              AMR            yes                            yes
# 25              AMR            yes                            yes
# 26              NaN            NaN                            NaN
# 27              NaN            NaN                            NaN
# 28              NaN            NaN                            NaN
#
#     Pilot Samples  Phase1 Samples  Final Phase Samples   Total
# 0             0.0             0.0                 99.0    99.0
# 1            91.0            97.0                103.0   106.0
# 2            94.0            89.0                104.0   105.0
# 3             0.0             0.0                101.0   101.0
# 4             0.0           100.0                108.0   112.0
# 5             0.0             0.0                 86.0    86.0
# 6             0.0             0.0                106.0   106.0
# 7             0.0             0.0                103.0   103.0
# 8             0.0             0.0                 96.0    96.0
# 9             0.0             0.0                103.0   103.0
# 10            0.0            61.0                 66.0    66.0
# 11            0.0             0.0                 96.0    96.0
# 12            0.0             0.0                 99.0    99.0
# 13            0.0             0.0                113.0   113.0
# 14          102.0            97.0                101.0   116.0
# 15            0.0             0.0                 85.0    85.0
# 16          106.0            88.0                109.0   116.0
# 17            0.0            89.0                 92.0    94.0
# 18            0.0            93.0                 99.0   100.0
# 19            0.0            14.0                107.0   107.0
# 20           66.0            98.0                108.0   110.0
# 21           94.0            85.0                 99.0   103.0
# 22            0.0            60.0                 94.0    95.0
# 23            0.0            66.0                 67.0    69.0
# 24            0.0             0.0                 86.0    86.0
# 25            0.0            55.0                105.0   105.0
# 26          553.0          1092.0               2535.0  2577.0
# 27            NaN             NaN                  NaN     NaN
# 28            NaN             NaN                  NaN     NaN

# %%
import pycountry

# %%
list_alpha_2 = [i.alpha_2 for i in list(pycountry.countries)]
list_alpha_3 = [i.alpha_3 for i in list(pycountry.countries)]

# %%
pycountry.countries.get(alpha_3="PEL").name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12632/3101497587.py in <module>
# ----> 1 pycountry.countries.get(alpha_3="PEL").name
#
# AttributeError: 'NoneType' object has no attribute 'name'

# %%
df['Population Code'].apply(lambda x: pycountry.countries.get(alpha_3=x))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12632/2745309796.py in <module>
# ----> 1 df['Population Code'].apply(lambda x: pycountry.countries.get(alpha_3=x))
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_12632/2745309796.py in <lambda>(x)
# ----> 1 df['Population Code'].apply(lambda x: pycountry.countries.get(alpha_3=x))
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pycountry\db.py in load_if_needed(self, *args, **kw)
#      37             with self._load_lock:
#      38                 self._load()
# ---> 39         return f(self, *args, **kw)
#      40
#      41     return load_if_needed
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pycountry\db.py in get(self, **kw)
#     109         field, value = kw.popitem()
#     110         if not isinstance(value, str):
# --> 111             raise LookupError()
#     112         # Normalize for case-insensitivity
#     113         value = value.lower()
#
# LookupError:

# %%
test = pycountry.countries.get(alpha_3="PEL")
